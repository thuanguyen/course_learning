# %%
library(ggstats)
packageVersion("ggstats")
# Out:
# [1] ‘0.10.0’

# %%
library(GGally)
# Out:
# Loading required package: ggplot2
#
# Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2
#
#
# Attaching package: ‘GGally’
#
#
# The following objects are masked from ‘package:ggstats’:
#
#     geom_stripped_cols, geom_stripped_rows, ggcoef_compare,
#     ggcoef_model, ggcoef_multinom, ggcoef_plot, signif_stars,
#     stat_cross, stat_prop, stat_weighted_mean, StatCross, StatProp,
#     StatWeightedMean

# %%
packageVersion("GGally")
find.package("ggstats")
find.package("GGally")
# Out:
# [1] ‘2.1.2’
# [1] "/opt/conda/envs/tvnEnv0013_r/lib/R/library/ggstats"
# [1] "/opt/conda/envs/tvnEnv0013_r/lib/R/library/GGally"
