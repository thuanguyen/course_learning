# %%
# %%bash
# wget https://d396qusza40orc.cloudfront.net/gencommand/gencommand_proj2_data.tar.gz
# mkdir gencommand_proj2_data
# tar -xvzf gencommand_proj2_data.tar.gz -C gencommand_proj2_data
# Out:
# --2025-12-17 03:58:41--  https://d396qusza40orc.cloudfront.net/gencommand/gencommand_proj2_data.tar.gz
# Resolving d396qusza40orc.cloudfront.net (d396qusza40orc.cloudfront.net)... 18.154.131.208, 18.154.131.195, 18.154.131.199, ...
# Connecting to d396qusza40orc.cloudfront.net (d396qusza40orc.cloudfront.net)|18.154.131.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10107897 (9.6M) [application/x-gzip]
# Saving to: ‘gencommand_proj2_data.tar.gz.1’
#
#      0K .......... .......... .......... .......... ..........  0% 21.3M 0s
#     50K .......... .......... .......... .......... ..........  1% 55.6M 0s
#    100K .......... .......... .......... .......... ..........  1%  106M 0s
#    150K .......... .......... .......... .......... ..........  2%  151M 0s
#    200K .......... .......... .......... .......... ..........  2%  229M 0s
#    250K .......... .......... .......... .......... ..........  3%  127M 0s
# ...
